# %%
import selenium

# %%
url = "https://www.youtube.com/watch?v=UUjLipg3CPI"

# %%
# Source - https://stackoverflow.com/a/73927769
# Posted by Stefan
# Retrieved 2026-02-28, License - CC BY-SA 4.0

element = WebDriverWait(driver, waittime).until(EC.presence_of_element_located((By.TAG_NAME, "ytd-menu-service-item-renderer")))
